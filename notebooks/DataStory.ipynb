# %% [markdown]
# # Data Story

# %% [markdown]
# ## Overview
#
# This notebook explains the bathymetry datasets used in this cookbook and how they connect to the original Geoscience Australia’s Semi-automated Morphological Mapping Tools (GA-SaMMT) workflow. The goal is to make the data provenance, data transformations, and open-science scope clear before readers start running geomorphology methods.
#
# In this notebook, we will:
#
# 1. Identify the original source of the GA-SaMMT sample data.
# 2. Explain why the cookbook uses GeoTIFF rasters instead of ArcGIS File Geodatabases.
# 3. Summarize the three bathymetry grids used throughout the examples.
# 4. Clarify what this cookbook does and does not attempt to reproduce.
# 5. Point readers to the notebooks that inspect, map, characterise, and classify features.

# %% [markdown]
# ## Prerequisites
#
# | What you should know | Why it matters here |
# |---|---|
# | Bathymetry rasters | The methods operate on gridded seabed elevation or depth surfaces. |
# | Coordinate reference systems | Area, distance, and slope measurements require projected coordinates. |
# | Basic Python/Jupyter | The cookbook is written as executable Jupyter notebooks. |
# | GA-SaMMT concept | The notebooks translate an ArcGIS Pro tool workflow into open Python examples. |
#
# :::{tip}
# Read this notebook first, then continue to **Metadata** before running the method notebooks. The metadata notebook checks the raster dimensions, CRS, cell size, nodata values, and bathymetry ranges used by the rest of the workflow.
# :::
#
# ---

# %% [markdown]
# ## Source and purpose
#
# The data used in this project come from the work presented in (Huang _et al._, 2023) _Rule-based semi-automated tools for mapping seabed morphology from bathymetry data_ available at
# [https://www.frontiersin.org/journals/marine-science/articles/10.3389/fmars.2023.1236788/full](https://www.frontiersin.org/journals/marine-science/articles/10.3389/fmars.2023.1236788/full).
#
# The original GA-SaMMT package is built around ArcGIS Pro Python toolboxes and sample datasets stored in File Geodatabases. This cookbook keeps the scientific workflow and educational logic, but uses open Python libraries and GeoTIFF inputs so that the methods can be explored without requiring ArcGIS Pro.
#
# :::{warning}
# This cookbook is an educational open-source translation of the workflow. It should not be described as an official replacement for GA-SaMMT unless outputs have been validated for a specific use case.
# :::

# %% [markdown]
# ## Study area

# %% [markdown]
# | Dataset | Why it is useful |
# |---|---|
# | `pc_bathy.tif` | Shows how small, dense seabed features respond to radius and area-threshold parameters. |
# | `os_bathy.tif` | Provides a high-resolution shelf example where many raster-derivative methods can be compared. |
# | `gifford_bathy.tif` | Demonstrates that mapping scale changes when the cell size and geomorphic setting change. |
#
# :::{tip} Parameter and data resolution
# A radius of 10 cells means a different physical distance in a 2 m raster, a 3 m raster, and a 50 m raster.
# :::

# %% [markdown]
# They were acquired during ship multibeam echosounder surveys, processed with CARIS HIPS/SIPS, and gridded to metre-scale raster surfaces. The original GA-SaMMT package stores its sample data in three File Geodatabases:
#
# - `Gifford.gdb`
# - `Oceanic_Shoals.gdb`
# - `Points_Cloates.gdb`
#
# The project uses the GeoTIFF converted version:
#
# - `gifford_bathy.tif`
# - `os_bathy.tif`
# - `pc_bathy.tif`
#
# | Cookbook data | Area | Acquisition and processing summary | Grid resolution |
# |---|---|---|---:|
# | `pc_bathy.tif` | Point Cloates Shelf, offshore Western Australia | Acquired in 2008 during survey SOL4769 using a Kongsberg EM3002 multibeam echosounder; processed with CARIS HIPS/SIPS v6.1 | 3 m |
# | `os_bathy.tif` | Oceanic Shoals / Bonaparte Basin, Timor Sea | Collected in 2012 during survey GA0339/SOL5650 using a Kongsberg EM3002D multibeam echosounder; processed with CARIS HIPS/SIPS v7.1 | 2 m |
# | `gifford_bathy.tif` | Gifford Seamounts, Gifford Marine Park, Tasman Sea | Compiled from two multibeam surveys: GA TAN0713 in 2007 using a Kongsberg EM300, and a GA/JAMSTEC survey in 2017 using a Kongsberg 12 kHz deep-water multibeam system; processed with CARIS HIPS/SIPS v7.1 | 50 m |
#
# The Gifford Seamounts grid represents a deeper-water setting than the shelf examples. The case study is centred around 26.79° S, 146.82° E, offshore eastern Australia, and covers water depths from approximately 250 m to 3,500 m. The area contains two seamounts, with ridges and valley-like bedforms on their flat tops and flanks.

# %% [markdown]
# ## Interactive map

# %% [markdown]
# An interactive `folium` map is used here to present the data's geographical position. See the [Metadata](./Metadata.ipynb) notebook.

# %%
from pathlib import Path
from html import escape
from IPython.display import HTML, display

map_path = Path("images/map.html")

if not map_path.exists():
    raise FileNotFoundError(f"Map file not found: {map_path}")

map_html = map_path.read_text(encoding="utf-8")

display(
    HTML(
        f"""
        <iframe
            srcdoc="{escape(map_html, quote=True)}"
            width="100%"
            height="400"
            style="border: none;"
        ></iframe>
        """
    )
)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
# ...

# %% [markdown]
# :::{note} Original tools and data samples...
# :class:dropdown
# The associated ArcGIS Pro tools and dataset samples are available [here](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/146832).
# :::
#
# :::{seealso} Full dataset with all datalinks...
# :class:dropdown
# As stated in the article:
# _The datasets presented in this study can be found in online repositories. The names of the repository/repositories and accession number(s) can be found below:
# Bynoe Harbour: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144556](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144556);
# Bonaparte Shelf: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/74866](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/74866);
# Bonaparte Basin: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/79006](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/79006);
# Leveque Shelf: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/83727](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/83727);
# Point Cloates Shelf: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/72005](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/72005);
# Broken Ridge: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/82625](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/82625);
# Tasmanian Seamounts: [https://doi.org/10.25919/qan1-qj27](https://doi.org/10.25919/qan1-qj27);
# Gifford Seamounts: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/121193](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/121193);
# Sabrina Slope: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144481](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144481)._
# :::

# %% [markdown]
# ## Scope and limitations
#
# This cookbook prioritizes open workflows. That means the first implementation should be judged by clarity, reproducibility, and scientific traceability before it is judged by speed or perfect ArcGIS reproduction.
#
# :::{warning} Important limitations to keep in mind:
# A mapped polygon or class label can not be considered "authoritative" simply because it was generated automatically. GA-SaMMT is semi-automated: domain review, parameter testing, and validation remain part of the workflow.
# :::

# %% [markdown]
# ## References and data links
#
# - Huang, Z., Nanson, R., McNeil, M., Wenderlich, M., Gafeira, J., Post, A., and Nichol, S. (2023). *Rule-based semi-automated tools for mapping seabed morphology from bathymetry data*. Frontiers in Marine Science, 10, 1236788. https://doi.org/10.3389/fmars.2023.1236788
# - GA-SaMMT tools and sample data: https://dx.doi.org/10.26186/146832
# - Dove, D. et al. (2020). *A two-part seabed geomorphology classification scheme; Part 1: morphology features glossary*. https://doi.org/10.5281/zenodo.4075248
#
# ---

# %% [markdown]
# ## Summary
#
# The cookbook uses three GeoTIFF bathymetry grids derived from the GA-SaMMT sample-data context. They give readers enough diversity to explore how seabed morphology tools behave across different resolutions and geomorphic settings, while keeping the workflow open and executable in Jupyter.
